# %%
import pandas as pd
import numpy as np

df538 = pd.read_csv("538 Ratings.csv")
df538.head()
# Out:
#    YEAR  TEAM NO            TEAM  SEED  ROUND  POWER RATING  POWER RATING RANK
# 0  2024     1067     Connecticut     1      1          95.6                  4
# 1  2024     1056         Houston     1     16          94.9                  8
# 2  2024     1033          Purdue     1      2          93.5                 15
# 3  2024     1038  North Carolina     1     16          90.2                 49
# 4  2024     1077         Arizona     2     16          91.6                 29

# %%
team_list = sorted(df538['TEAM'].unique().tolist())
team_list
# Out:
# ['Abilene Christian',
#  'Akron',
#  'Alabama',
#  'Appalachian St.',
#  'Arizona',
#  'Arizona St.',
#  'Arkansas',
#  'Auburn',
#  'Austin Peay',
#  'BYU',
#  'Baylor',
#  'Belmont',
#  'Boise St.',
#  'Bradley',
#  'Bryant',
#  'Bucknell',
#  'Buffalo',
#  'Butler',
#  'Cal St. Bakersfield',
#  'Cal St. Fullerton',
#  'California',
#  'Chattanooga',
#  'Cincinnati',
#  'Clemson',
#  'Cleveland St.',
#  'Colgate',
#  'College of Charleston',
#  'Colorado',
#  'Colorado St.',
#  'Connecticut',
#  'Creighton',
#  'Davidson',
#  'Dayton',
#  'Delaware',
#  'Drake',
#  'Drexel',
#  'Duke',
#  'Duquesne',
#  'East Tennessee St.',
#  'Eastern Washington',
#  'Fairleigh Dickinson',
#  'Florida',
#  'Florida Atlantic',
#  'Florida Gulf Coast',
#  'Florida St.',
#  'Fresno St.',
#  'Furman',
#  'Gardner Webb',
#  'Georgetown',
#  'Georgia St.',
#  'Georgia Tech',
#  'Gonzaga',
#  'Grambling St.',
#  'Grand Canyon',
#  'Green Bay',
#  'Hampton',
#  'Hartford',
#  'Hawaii',
#  'Holy Cross',
#  'Houston',
#  'Howard',
#  'Illinois',
#  'Indiana',
#  'Iona',
#  'Iowa',
#  'Iowa St.',
#  'Jacksonville St.',
#  'James Madison',
#  'Kansas',
#  'Kansas St.',
#  'Kennesaw St.',
#  'Kent St.',
#  'Kentucky',
#  'LIU Brooklyn',
#  'LSU',
#  'Liberty',
#  'Lipscomb',
#  'Little Rock',
#  'Long Beach St.',
#  'Longwood',
#  'Louisiana Lafayette',
#  'Louisville',
#  'Loyola Chicago',
#  'Marquette',
#  'Marshall',
#  'Maryland',
#  'McNeese St.',
#  'Memphis',
#  'Miami FL',
#  'Michigan',
#  'Michigan St.',
#  'Middle Tennessee',
#  'Minnesota',
#  'Mississippi',
#  'Mississippi St.',
#  'Missouri',
#  'Montana',
#  'Montana St.',
#  'Morehead St.',
#  "Mount St. Mary's",
#  'Murray St.',
#  'Nebraska',
#  'Nevada',
#  'New Mexico',
#  'New Mexico St.',
#  'New Orleans',
#  'Norfolk St.',
#  'North Carolina',
#  'North Carolina Central',
#  'North Carolina St.',
#  'North Dakota',
#  'North Dakota St.',
#  'North Texas',
#  'Northeastern',
#  'Northern Iowa',
#  'Northern Kentucky',
#  'Northwestern',
#  'Notre Dame',
#  'Oakland',
#  'Ohio',
#  'Ohio St.',
#  'Oklahoma',
#  'Oklahoma St.',
#  'Old Dominion',
#  'Oral Roberts',
#  'Oregon',
#  'Oregon St.',
#  'Penn',
#  'Penn St.',
#  'Pittsburgh',
#  'Prairie View A&M',
#  'Princeton',
#  'Providence',
#  'Purdue',
#  'Radford',
#  'Rhode Island',
#  'Richmond',
#  'Rutgers',
#  'SMU',
#  "Saint Joseph's",
#  'Saint Louis',
#  "Saint Mary's",
#  "Saint Peter's",
#  'Samford',
#  'San Diego St.',
#  'San Francisco',
#  'Seton Hall',
#  'South Carolina',
#  'South Dakota St.',
#  'Southeast Missouri St.',
#  'Southern',
#  'St. Bonaventure',
#  "St. John's",
#  'Stephen F. Austin',
#  'Stetson',
#  'Stony Brook',
#  'Syracuse',
#  'TCU',
#  'Temple',
#  'Tennessee',
#  'Texas',
#  'Texas A&M',
#  'Texas A&M Corpus Chris',
#  'Texas Southern',
#  'Texas Tech',
#  'Troy',
#  'Tulsa',
#  'UAB',
#  'UC Davis',
#  'UC Irvine',
#  'UC Santa Barbara',
#  'UCF',
#  'UCLA',
#  'UMBC',
#  'UNC Asheville',
#  'UNC Greensboro',
#  'UNC Wilmington',
#  'USC',
#  'Utah',
#  'Utah St.',
#  'VCU',
#  'Vanderbilt',
#  'Vermont',
#  'Villanova',
#  'Virginia',
#  'Virginia Tech',
#  'Wagner',
#  'Wake Forest',
#  'Washington',
#  'Washington St.',
#  'Weber St.',
#  'West Virginia',
#  'Western Kentucky',
#  'Wichita St.',
#  'Winthrop',
#  'Wisconsin',
#  'Wofford',
#  'Wright St.',
#  'Wyoming',
#  'Xavier',
#  'Yale']

# %%
dfAP = pd.read_csv("AP Poll Data.csv")
dfAP.head()
# Out:
#    YEAR  WEEK  TEAM NO         TEAM  SEED  ROUND    W    L  AP VOTES  AP RANK  \
# 0  2026     1   1173.0       Purdue   2.0    0.0  0.0  0.0    1485.0      1.0
# 1  2026     1   1199.0      Houston   2.0    0.0  0.0  0.0    1459.0      2.0
# 2  2026     1   1206.0      Florida   1.0    0.0  0.0  0.0    1382.0      3.0
# 3  2026     1   1208.0  Connecticut   2.0    0.0  0.0  0.0    1299.0      4.0
# 4  2026     1   1165.0   St. John's   5.0    0.0  0.0  0.0    1203.0      5.0
#
#    RANK?
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
team_list_AP = sorted(dfAP['TEAM'].unique().tolist())
team_list_AP
# Out:
# ['Abilene Christian',
#  'Akron',
#  'Alabama',
#  'American',
#  'Appalachian St.',
#  'Arizona',
#  'Arizona St.',
#  'Arkansas',
#  'Arkansas St.',
#  'Army',
#  'Auburn',
#  'Austin Peay',
#  'BYU',
#  'Ball St.',
#  'Baylor',
#  'Belmont',
#  'Boise St.',
#  'Boise State',
#  'Boston College',
#  'Bradley',
#  'Bucknell',
#  'Buffalo',
#  'Butler',
#  'Cal St. Bakersfield',
#  'Cal St. Fullerton',
#  'Cal St. Northridge',
#  'California',
#  'Central Michigan',
#  'Charlotte',
#  'Chattanooga',
#  'Cincinnati',
#  'Clemson',
#  'Cleveland St.',
#  'Coastal Carolina',
#  'College of Charleston',
#  'Colorado',
#  'Colorado St.',
#  'Colorado State',
#  'Columbia',
#  'Connecticut',
#  'Cornell',
#  'Creighton',
#  'Davidson',
#  'Dayton',
#  'DePaul',
#  'Drake',
#  'Drexel',
#  'Duke',
#  'Duquesne',
#  'East Tennessee St.',
#  'Florida',
#  'Florida Atlantic',
#  'Florida Gulf Coast',
#  'Florida St.',
#  'Florida State',
#  'Fresno St.',
#  'Furman',
#  'Gardner Webb',
#  'George Mason',
#  'George Washington',
#  'Georgetown',
#  'Georgia',
#  'Georgia Tech',
#  'Gonzaga',
#  'Grambling St.',
#  'Grand Canyon',
#  'Green Bay',
#  'Harvard',
#  'Hawaii',
#  'High Point',
#  'Hofstra',
#  'Holy Cross',
#  'Houston',
#  'Illinois',
#  'Illinois St.',
#  'Indiana',
#  'Indiana St.',
#  'Iona',
#  'Iowa',
#  'Iowa St.',
#  'Iowa State',
#  'James Madison',
#  'Kansas',
#  'Kansas St.',
#  'Kent St.',
#  'Kentucky',
#  'LIU Brooklyn',
#  'LSU',
#  'La Salle',
#  'Lehigh',
#  'Liberty',
#  'Lipscomb',
#  'Little Rock',
#  'Long Beach St.',
#  'Longwood',
#  'Louisiana Lafayette',
#  'Louisiana Tech',
#  'Louisville',
#  'Loyola Chicago',
#  'Loyola Maryland',
#  'Marquette',
#  'Marshall',
#  'Maryland',
#  'Massachusetts',
#  'McNeese St.',
#  'Memphis',
#  'Mercer',
#  'Miami',
#  'Miami FL',
#  'Miami OH',
#  'Michigan',
#  'Michigan St.',
#  'Michigan State',
#  'Middle Tennessee',
#  'Minnesota',
#  'Mississippi',
#  'Mississippi St.',
#  'Mississippi State',
#  'Missouri',
#  'Missouri St.',
#  'Missouri State',
#  'Monmouth',
#  'Montana',
#  "Mount St. Mary's",
#  'Murray St.',
#  'Murray State',
#  'NJIT',
#  'Navy',
#  'Nebraska',
#  'Nevada',
#  'New Mexico',
#  'New Mexico St.',
#  'New Mexico State',
#  'New Orleans',
#  'Niagara',
#  'North Carolina',
#  'North Carolina Central',
#  'North Carolina St.',
#  'North Carollina',
#  'North Dakota',
#  'North Florida',
#  'North Texas',
#  'Northeastern',
#  'Northern Iowa',
#  'Northwestern',
#  'Notre Dame',
#  'Oakland',
#  'Ohio',
#  'Ohio St.',
#  'Ohio State',
#  'Oklahoma',
#  'Oklahoma St.',
#  'Oklahoma State',
#  'Old Dominion',
#  'Oral Roberts',
#  'Oregon',
#  'Oregon St.',
#  'Penn',
#  'Penn St.',
#  'Pittsburgh',
#  'Portland',
#  'Princeton',
#  'Providence',
#  'Purdue',
#  'Purdue Fort Wayne',
#  'Radford',
#  'Rhode Island',
#  'Richmond',
#  'Rider',
#  'Robert Morris',
#  'Rutgers',
#  'SMU',
#  "Saint Joseph's",
#  'Saint Louis',
#  "Saint Mary's",
#  'Sam Houston St.',
#  'Samford',
#  'San Diego',
#  'San Diego St.',
#  'San Diego State',
#  'San Francisco',
#  'Santa Clara',
#  'Seattle',
#  'Seton Hall',
#  'Siena',
#  'South Alabama',
#  'South Carolina',
#  'South Dakota St.',
#  'South Dakota State',
#  'South Florida',
#  'Southern Illinois',
#  'Southern Miss',
#  'St. Bonaventure',
#  "St. John's",
#  'Stanford',
#  'Stephen F. Austin',
#  'Stony Brook',
#  'Syracuse',
#  'TCU',
#  'Temple',
#  'Tennessee',
#  'Tennessee St.',
#  'Texas',
#  'Texas A&M',
#  'Texas State',
#  'Texas Tech',
#  'Toledo',
#  'Towson',
#  'Tulane',
#  'Tulsa',
#  'UAB',
#  'UC Davis',
#  'UC Irvine',
#  'UC San Diego',
#  'UC Santa Barbara',
#  'UCF',
#  'UCLA',
#  'UMBC',
#  'UNC Asheville',
#  'UNC Greensboro',
#  'UNC Wilmington',
#  'UNLV',
#  'USC',
#  'UT Arlington',
#  'UTEP',
#  'Utah',
#  'Utah St.',
#  'Utah State',
#  'Utah Valley',
#  'VCU',
#  'VMI',
#  'Valparaiso',
#  'Vanderbilt',
#  'Vermont',
#  'Villanova',
#  'Virginia',
#  'Virginia Tech',
#  'Wagner',
#  'Wake Forest',
#  'Washington',
#  'Washington St.',
#  'Weber St.',
#  'Weber State',
#  'West Virginia',
#  'Western Carolina',
#  'Western Illinois',
#  'Western Kentucky',
#  'Western Michigan',
#  'Wichita St.',
#  'William & Mary',
#  'Winthrop',
#  'Wisconsin',
#  'Wofford',
#  'Wright St.',
#  'Wyoming',
#  'Xavier',
#  'Yale']

# %%
len(team_list_AP)
# Out:
# 257

# %%
dfseed = pd.read_csv('Seed Results.csv')
dfseed.head()
# Out:
#    SEED  PAKE  PAKE RANK  PASE  PASE RANK  GAMES    W   L   WIN%  R64  R32  \
# 0    11  14.2          2  14.8          1    127   59  68  0.465   68   33
# 1    15   3.8          5   5.2          2     80   12  68  0.150   68    7
# 2     3   5.9          3   4.0          3    196  129  67  0.658   68   60
# 3     4   2.5          6   3.8          4    177  110  67  0.621   68   53
# 4     8  -0.3          8   3.0          5    119   51  68  0.429   68   35
#
#    S16  E8  F4  F2  CHAMP  TOP2  CHAMP%
# 0   16   6   4   0      0     0  11.80%
# 1    4   1   0   0      0     0   0.00%
# 2   40  20   5   3      1     0  80.70%
# 3   37  11   6   2      1     0  75.80%
# 4    7   3   3   3      0     0  16.30%

# %%
dfseed['Rank Diff'] = dfseed['PAKE RANK'] - dfseed['SEED']
dfseed
# Out:
#     SEED  PAKE  PAKE RANK  PASE  PASE RANK  GAMES    W   L   WIN%  R64  R32  \
# 0     11  14.2          2  14.8          1    127   59  68  0.465   68   33
# 1     15   3.8          5   5.2          2     80   12  68  0.150   68    7
# 2      3   5.9          3   4.0          3    196  129  67  0.658   68   60
# 3      4   2.5          6   3.8          4    177  110  67  0.621   68   53
# 4      8  -0.3          8   3.0          5    119   51  68  0.429   68   35
# 5      9  -1.3         10   2.8          6    112   44  68  0.393   68   33
# 6     12   3.8          4   2.6          7    105   37  68  0.352   68   28
# 7      7   1.0          7   1.6          8    129   62  67  0.481   68   41
# 8     16  -1.1          9   1.1          9     70    2  68  0.029   68    2
# 9     13  -3.6         11   0.4         10     85   17  68  0.200   68   15
# 10     1  23.9          1  -2.0         11    280  225  55  0.804   68   66
# 11    10  -7.6         14  -2.2         12    107   39  68  0.364   68   27
# 12    14  -7.3         13  -2.6         13     76    8  68  0.105   68    8
# 13     5 -10.9         15  -2.8         14    143   75  68  0.524   68   40
# 14     2  -5.5         12  -9.5         15    216  149  67  0.690   68   61
# 15     6 -19.2         16 -19.8         16    120   52  68  0.433   68   35
#
#     S16  E8  F4  F2  CHAMP  TOP2  CHAMP%  Rank Diff
# 0    16   6   4   0      0     0  11.80%         -9
# 1     4   1   0   0      0     0   0.00%        -10
# 2    40  20   5   3      1     0  80.70%          0
# 3    37  11   6   2      1     0  75.80%          2
# 4     7   3   3   3      0     0  16.30%          0
# 5     5   4   2   0      0     0  12.40%          1
# 6     8   1   0   0      0     0   4.60%         -8
# 7    12   4   3   1      1     0  22.60%          0
# 8     0   0   0   0      0     0   0.00%         -7
# 9     2   0   0   0      0     0   0.60%         -2
# 10   56  42  28  20     13    68  99.90%          0
# 11    8   3   1   0      0     0  13.50%          4
# 12    0   0   0   0      0     0   0.50%         -1
# 13   21   7   5   2      0     0  51.00%         10
# 14   44  29  11   3      1    68  97.70%         10
# 15   12   5   0   0      0     0  31.20%         10

# %%
dfseed['HIGH_PERFORMANCE'] = dfseed['Rank Diff'] < -2
dfseed['LOW_PERFORMANCE'] = dfseed['Rank Diff'] > 2
dfseed[['SEED', 'PAKE RANK', 'Rank Diff', 'HIGH_PERFORMANCE', 'LOW_PERFORMANCE']]
# Out:
#     SEED  PAKE RANK  Rank Diff  HIGH_PERFORMANCE  LOW_PERFORMANCE
# 0     11          2         -9              True            False
# 1     15          5        -10              True            False
# 2      3          3          0             False            False
# 3      4          6          2             False            False
# 4      8          8          0             False            False
# 5      9         10          1             False            False
# 6     12          4         -8              True            False
# 7      7          7          0             False            False
# 8     16          9         -7              True            False
# 9     13         11         -2             False            False
# 10     1          1          0             False            False
# 11    10         14          4             False             True
# 12    14         13         -1             False            False
# 13     5         15         10             False             True
# 14     2         12         10             False             True
# 15     6         16         10             False             True

# %% [markdown]
# ### Train a naive model on Tournament Matchups

# %%
df_tourgames = pd.read_csv('Tournament Matchups.csv')
df_tourgames.describe()
# Out:
#               YEAR  BY YEAR NO      TEAM NO         SEED        ROUND  \
# count  2288.000000  2288.00000  2288.000000  2288.000000  2288.000000
# mean   2016.917832  1144.50000   610.317745     6.764423    28.543706
# std       5.627271   660.63303   356.098426     4.557077    23.118974
# min    2008.000000     1.00000     1.000000     1.000000     1.000000
# 25%    2012.000000   572.75000   302.750000     3.000000     8.000000
# 50%    2017.000000  1144.50000   607.500000     6.000000    32.000000
# 75%    2022.000000  1716.25000   918.000000    11.000000    64.000000
# max    2026.000000  2288.00000  1215.000000    16.000000    64.000000
#
#        CURRENT ROUND        SCORE
# count    2288.000000  2140.000000
# mean       43.477273    69.821963
# std        22.133423    12.003840
# min         2.000000    29.000000
# 25%        32.000000    61.000000
# 50%        64.000000    70.000000
# 75%        64.000000    78.000000
# max        64.000000   113.000000

# %%
df_tourgames.dropna(inplace=True)
df_tourgames.describe()
# Out:
#              YEAR   BY YEAR NO      TEAM NO         SEED        ROUND  \
# count  2140.00000  2140.000000  2140.000000  2140.000000  2140.000000
# mean   2016.28972  1070.500000   570.699533     6.778037    28.898131
# std       5.26832   617.909109   333.578133     4.563590    22.873187
# min    2008.00000     1.000000     1.000000     1.000000     1.000000
# 25%    2012.00000   535.750000   284.000000     3.000000     8.000000
# 50%    2016.00000  1070.500000   568.000000     6.000000    32.000000
# 75%    2021.00000  1605.250000   859.000000    11.000000    64.000000
# max    2025.00000  2140.000000  1147.000000    16.000000    64.000000
#
#        CURRENT ROUND        SCORE
# count    2140.000000  2140.000000
# mean       43.314019    69.821963
# std        22.366000    12.003840
# min         2.000000    29.000000
# 25%        32.000000    61.000000
# 50%        64.000000    70.000000
# 75%        64.000000    78.000000
# max        64.000000   113.000000

# %%
df_tourgames.head(n=20)
# Out:
#      YEAR  BY YEAR NO  TEAM NO            TEAM  SEED  ROUND  CURRENT ROUND  \
# 148  2025        2140     1141          Auburn     1      4             64
# 149  2025        2139     1145     Alabama St.    16     64             64
# 150  2025        2138     1119      Louisville     8     64             64
# 151  2025        2137     1134       Creighton     9     32             64
# 152  2025        2136     1114        Michigan     5     16             64
# 153  2025        2135     1089    UC San Diego    12     64             64
# 154  2025        2134     1092       Texas A&M     4     32             64
# 155  2025        2133     1080            Yale    13     64             64
# 156  2025        2132     1112     Mississippi     6     16             64
# 157  2025        2131     1104  North Carolina    11     64             64
# 158  2025        2130     1124        Iowa St.     3     32             64
# 159  2025        2129     1120        Lipscomb    14     64             64
# 160  2025        2128     1118       Marquette     7     64             64
# 161  2025        2127     1106      New Mexico    10     32             64
# 162  2025        2126     1113    Michigan St.     2      8             64
# 163  2025        2125     1139          Bryant    15     64             64
# 164  2025        2124     1131         Florida     1      1             64
# 165  2025        2123     1105     Norfolk St.    16     64             64
# 166  2025        2122     1135     Connecticut     8     32             64
# 167  2025        2121     1103        Oklahoma     9     64             64
#
#      SCORE
# 148   83.0
# 149   63.0
# 150   75.0
# 151   89.0
# 152   68.0
# 153   65.0
# 154   80.0
# 155   71.0
# 156   71.0
# 157   64.0
# 158   82.0
# 159   55.0
# 160   66.0
# 161   75.0
# 162   87.0
# 163   62.0
# 164   95.0
# 165   69.0
# 166   67.0
# 167   59.0

# %%
#dataframe transformation
df_team1 = df_tourgames.iloc[::2].reset_index(drop=True)
df_team2 = df_tourgames.iloc[1::2].reset_index(drop=True)
df_team1.head()
# Out:
#    YEAR  BY YEAR NO  TEAM NO         TEAM  SEED  ROUND  CURRENT ROUND  SCORE
# 0  2025        2140     1141       Auburn     1      4             64   83.0
# 1  2025        2138     1119   Louisville     8     64             64   75.0
# 2  2025        2136     1114     Michigan     5     16             64   68.0
# 3  2025        2134     1092    Texas A&M     4     32             64   80.0
# 4  2025        2132     1112  Mississippi     6     16             64   71.0

# %%
df_games = pd.DataFrame({
    'YEAR': df_team1['YEAR'],
    'ROUND': df_team1['ROUND'],
    'CURRENT ROUND': df_team1['CURRENT ROUND'],
    'TEAM NO 1': df_team1['TEAM NO'],
    'TEAM 1': df_team1['TEAM'],
    'SEED 1': df_team1['SEED'],
    'SCORE 1': df_team1['SCORE'],
    'TEAM NO 2': df_team2['TEAM NO'],
    'TEAM 2': df_team2['TEAM'],
    'SEED 2': df_team2['SEED'],
    'SCORE 2': df_team2['SCORE'],
    'TEAM 1 WIN': (df_team1['SCORE'] > df_team2['SCORE']).astype(int)
})

df_games.head()
# Out:
#    YEAR  ROUND  CURRENT ROUND  TEAM NO 1       TEAM 1  SEED 1  SCORE 1  \
# 0  2025      4             64       1141       Auburn       1     83.0
# 1  2025     64             64       1119   Louisville       8     75.0
# 2  2025     16             64       1114     Michigan       5     68.0
# 3  2025     32             64       1092    Texas A&M       4     80.0
# 4  2025     16             64       1112  Mississippi       6     71.0
#
#    TEAM NO 2          TEAM 2  SEED 2  SCORE 2  TEAM 1 WIN
# 0       1145     Alabama St.      16     63.0           1
# 1       1134       Creighton       9     89.0           0
# 2       1089    UC San Diego      12     65.0           1
# 3       1080            Yale      13     71.0           1
# 4       1104  North Carolina      11     64.0           1

# %%
df_games.describe()
# Out:
#               YEAR        ROUND  CURRENT ROUND    TEAM NO 1       SEED 1  \
# count  1070.000000  1070.000000    1070.000000  1070.000000  1070.000000
# mean   2016.289720    23.239252      43.314019   571.079439     4.742991
# std       5.269552    19.982938      22.371230   334.354817     3.186196
# min    2008.000000     1.000000       2.000000     1.000000     1.000000
# 25%    2012.000000     8.000000      32.000000   285.250000     2.000000
# 50%    2016.000000    16.000000      64.000000   568.000000     5.000000
# 75%    2021.000000    32.000000      64.000000   860.000000     7.000000
# max    2025.000000    64.000000      64.000000  1146.000000    16.000000
#
#            SCORE 1    TEAM NO 2       SEED 2      SCORE 2   TEAM 1 WIN
# count  1070.000000  1070.000000  1070.000000  1070.000000  1070.000000
# mean     72.405607   570.319626     8.813084    67.238318     0.624299
# std      12.036970   332.955556     4.819726    11.404717     0.484530
# min      39.000000     1.000000     1.000000    29.000000     0.000000
# 25%      63.250000   284.000000     4.000000    59.000000     0.000000
# 50%      72.000000   568.500000    10.000000    67.000000     1.000000
# 75%      80.750000   857.750000    13.000000    75.000000     1.000000
# max     113.000000  1147.000000    16.000000   113.000000     1.000000

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.linear_model import LogisticRegression

len(df_games[df_games['YEAR'] == 2025])
# Out:
# 63

# %%
###for this one, we can just use everydata before 2023 to train, and test on 2023,24,25
df_test = df_games[df_games['YEAR'] >= 2023]
df_test['WINNING PRED'] = df_test['SEED 1'] < df_test['SEED 2']
accuracy = accuracy_score(df_test['TEAM 1 WIN'], df_test['WINNING PRED'])
accuracy
# Out:
# C:\Users\BQFAN\AppData\Local\Temp\ipykernel_45532\697825778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['WINNING PRED'] = df_test['SEED 1'] < df_test['SEED 2']
# 0.7301587301587301

# %%
print(df_test[['SEED 1', 'SEED 2', 'TEAM 1 WIN', 'WINNING PRED']])
# Out:
#      SEED 1  SEED 2  TEAM 1 WIN  WINNING PRED
# 0         1      16           1          True
# 1         8       9           0          True
# 2         5      12           1          True
# 3         4      13           1          True
# 4         6      11           1          True
# ..      ...     ...         ...           ...
# 184       5       2           1         False
# 185       4       3           1         False
# 186       5       9           1          True
# 187       5       4           0         False
# 188       5       4           0         False
#
# [189 rows x 4 columns]

# %%
confusion_matrix(df_test['TEAM 1 WIN'], df_test['WINNING PRED'])
# Out:
# array([[ 35,  32],
#        [ 19, 103]], dtype=int64)

# %%
df_games.to_csv('GAME RECORDS.csv', index=False)

# %%
df_games.columns
# Out:
# Index(['YEAR', 'ROUND', 'CURRENT ROUND', 'TEAM NO 1', 'TEAM 1', 'SEED 1',
#        'SCORE 1', 'TEAM NO 2', 'TEAM 2', 'SEED 2', 'SCORE 2', 'TEAM 1 WIN'],
#       dtype='object')

# %% [markdown]
# ### Now let's see if 538 power ratings are more scientific

# %%
df_enhanced = df_games.merge(
    df538[['YEAR', 'TEAM NO', 'POWER RATING', 'POWER RATING RANK']],
    left_on=['YEAR', 'TEAM NO 1'],
    right_on=['YEAR', 'TEAM NO'],
    how='left'
)
df_enhanced.rename(columns={'POWER RATING': 'POWER RATING 1', 'POWER RATING RANK': 'POWER RANKING 1'}, inplace=True)
df_enhanced.head()
# Out:
#    YEAR  ROUND  CURRENT ROUND  TEAM NO 1       TEAM 1  SEED 1  SCORE 1  \
# 0  2025      4             64       1141       Auburn       1     83.0
# 1  2025     64             64       1119   Louisville       8     75.0
# 2  2025     16             64       1114     Michigan       5     68.0
# 3  2025     32             64       1092    Texas A&M       4     80.0
# 4  2025     16             64       1112  Mississippi       6     71.0
#
#    TEAM NO 2          TEAM 2  SEED 2  SCORE 2  TEAM 1 WIN  TEAM NO  \
# 0       1145     Alabama St.      16     63.0           1      NaN
# 1       1134       Creighton       9     89.0           0      NaN
# 2       1089    UC San Diego      12     65.0           1      NaN
# 3       1080            Yale      13     71.0           1      NaN
# 4       1104  North Carolina      11     64.0           1      NaN
#
#    POWER RATING 1  POWER RANKING 1
# 0             NaN              NaN
# 1             NaN              NaN
# 2             NaN              NaN
# 3             NaN              NaN
# 4             NaN              NaN

# %%
df_enhanced[df_enhanced['YEAR'] == 2024].head(10)
# Out:
#     YEAR  ROUND  CURRENT ROUND  TEAM NO 1            TEAM 1  SEED 1  SCORE 1  \
# 63  2024      1             64       1067       Connecticut       1     91.0
# 64  2024     64             64       1060  Florida Atlantic       8     65.0
# 65  2024     16             64       1029     San Diego St.       5     69.0
# 66  2024     64             64       1076            Auburn       4     76.0
# 67  2024     64             64       1073               BYU       6     67.0
# 68  2024      8             64       1054          Illinois       3     85.0
# 69  2024     32             64       1015    Washington St.       7     66.0
# 70  2024     16             64       1053          Iowa St.       2     82.0
# 71  2024     16             64       1038    North Carolina       1     90.0
# 72  2024     64             64       1044   Mississippi St.       8     51.0
#
#     TEAM NO 2            TEAM 2  SEED 2  SCORE 2  TEAM 1 WIN  TEAM NO  \
# 63       1026           Stetson      16     52.0           1   1067.0
# 64       1036      Northwestern       9     77.0           0   1060.0
# 65       1020               UAB      12     65.0           1   1029.0
# 66       1012              Yale      13     78.0           0   1076.0
# 67       1062          Duquesne      11     71.0           0   1073.0
# 68       1042      Morehead St.      14     69.0           1   1054.0
# 69       1064             Drake      10     61.0           1   1015.0
# 70       1027  South Dakota St.      15     65.0           1   1053.0
# 71       1016            Wagner      16     62.0           1   1038.0
# 72       1045      Michigan St.       9     69.0           0   1044.0
#
#     POWER RATING 1  POWER RANKING 1
# 63            95.6              4.0
# 64            84.9            191.0
# 65            85.6            171.0
# 66            90.9             39.0
# 67            86.1            154.0
# 68            89.4             64.0
# 69            83.5            247.0
# 70            91.0             37.0
# 71            90.2             49.0
# 72            85.0            189.0

# %%
df_enhanced.drop('TEAM NO', axis=1, inplace=True)

df_enhanced = df_enhanced.merge(
    df538[['YEAR', 'TEAM NO', 'POWER RATING', 'POWER RATING RANK']],
    left_on=['YEAR', 'TEAM NO 2'],
    right_on=['YEAR', 'TEAM NO'],
    how='left'
)
df_enhanced.rename(columns={'POWER RATING': 'POWER RATING 2', 'POWER RATING RANK': 'POWER RANKING 2'}, inplace=True)
df_enhanced.drop('TEAM NO', axis=1, inplace=True)

df_enhanced[df_enhanced['YEAR'] == 2024].head(10)
# Out:
#     YEAR  ROUND  CURRENT ROUND  TEAM NO 1            TEAM 1  SEED 1  SCORE 1  \
# 63  2024      1             64       1067       Connecticut       1     91.0
# 64  2024     64             64       1060  Florida Atlantic       8     65.0
# 65  2024     16             64       1029     San Diego St.       5     69.0
# 66  2024     64             64       1076            Auburn       4     76.0
# 67  2024     64             64       1073               BYU       6     67.0
# 68  2024      8             64       1054          Illinois       3     85.0
# 69  2024     32             64       1015    Washington St.       7     66.0
# 70  2024     16             64       1053          Iowa St.       2     82.0
# 71  2024     16             64       1038    North Carolina       1     90.0
# 72  2024     64             64       1044   Mississippi St.       8     51.0
#
#     TEAM NO 2            TEAM 2  SEED 2  SCORE 2  TEAM 1 WIN  POWER RATING 1  \
# 63       1026           Stetson      16     52.0           1            95.6
# 64       1036      Northwestern       9     77.0           0            84.9
# 65       1020               UAB      12     65.0           1            85.6
# 66       1012              Yale      13     78.0           0            90.9
# 67       1062          Duquesne      11     71.0           0            86.1
# 68       1042      Morehead St.      14     69.0           1            89.4
# 69       1064             Drake      10     61.0           1            83.5
# 70       1027  South Dakota St.      15     65.0           1            91.0
# 71       1016            Wagner      16     62.0           1            90.2
# 72       1045      Michigan St.       9     69.0           0            85.0
#
#     POWER RANKING 1  POWER RATING 2  POWER RANKING 2
# 63              4.0            70.7            515.0
# 64            191.0            83.5            247.0
# 65            171.0            78.5            402.0
# 66             39.0            79.6            382.0
# 67            154.0            79.0            394.0
# 68             64.0            75.9            450.0
# 69            247.0            82.9            272.0
# 70             37.0            74.5            470.0
# 71             49.0            66.4            541.0
# 72            189.0            87.1            121.0

# %%
df_enhanced_2324 = df_enhanced[df_enhanced['YEAR'].isin([2023, 2024])]
df_enhanced_2324['WINNER PRED'] = df_enhanced_2324['POWER RATING 1'] > df_enhanced_2324['POWER RATING 2']
accuracy_2324 = accuracy_score(df_enhanced_2324['TEAM 1 WIN'], df_enhanced_2324['WINNER PRED'])
accuracy_2324
# Out:
# C:\Users\BQFAN\AppData\Local\Temp\ipykernel_45532\3967105481.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_enhanced_2324['WINNER PRED'] = df_enhanced_2324['POWER RATING 1'] > df_enhanced_2324['POWER RATING 2']
# 0.6984126984126984

# %%
bartovikANdf = pd.read_csv('Barttorvik Away-Neutral.csv')
bartovikANdf.describe()
# Out:
#               YEAR      TEAM NO      TEAM ID         SEED        ROUND  \
# count  1215.000000  1215.000000  1215.000000  1215.000000  1215.000000
# mean   2016.891358   608.000000   127.923457     8.771193    41.513580
# std       5.561670   350.884596    73.244900     4.671092    24.445439
# min    2008.000000     1.000000     1.000000     1.000000     0.000000
# 25%    2012.000000   304.500000    68.000000     5.000000    16.000000
# 50%    2017.000000   608.000000   125.000000     9.000000    32.000000
# 75%    2022.000000   911.500000   196.500000    13.000000    64.000000
# max    2026.000000  1215.000000   260.000000    16.000000    68.000000
#
#            BADJ EM       BADJ O       BADJ D      BARTHAG        GAMES  ...  \
# count  1215.000000  1215.000000  1215.000000  1215.000000  1215.000000  ...
# mean     13.717037   110.969547    97.252510     0.779635    16.695473  ...
# std       9.381822     7.015801     5.449802     0.171822     2.263769  ...
# min     -18.900000    88.500000    80.600000     0.098000     6.000000  ...
# 25%       8.100000   106.500000    93.500000     0.710000    15.000000  ...
# 50%      15.100000   110.800000    96.800000     0.842000    17.000000  ...
# 75%      19.800000   115.600000   100.700000     0.899000    18.000000  ...
# max      37.700000   133.600000   116.000000     0.984000    24.000000  ...
#
#         BADJT RANK  AVG HGT RANK  EFF HGT RANK     EXP RANK  TALENT RANK  \
# count  1215.000000   1215.000000   1215.000000  1215.000000  1215.000000
# mean    188.618930    129.161317    130.538272   158.174486   100.637037
# std     102.606029     98.110898     98.559911    99.077263    96.292350
# min       1.000000      1.000000      1.000000     1.000000     1.000000
# 25%     103.500000     43.500000     46.000000    73.500000    25.500000
# 50%     190.000000    108.000000    111.000000   152.000000    65.000000
# 75%     280.000000    201.000000    205.000000   239.000000   152.500000
# max     365.000000    363.000000    364.000000   363.000000   365.000000
#
#           FT% RANK  OP FT% RANK    PPPO RANK    PPPD RANK  ELITE SOS RANK
# count  1215.000000  1215.000000  1215.000000  1215.000000     1215.000000
# mean    146.279835   179.684774    80.332510   100.302881      110.617284
# std      97.812107   101.649397    70.204254    81.660307      102.852268
# min       1.000000     1.000000     1.000000     1.000000        1.000000
# 25%      60.000000    92.000000    25.000000    33.500000       30.000000
# 50%     135.000000   180.000000    61.000000    80.000000       69.000000
# 75%     226.000000   268.000000   117.000000   150.000000      183.000000
# max     361.000000   362.000000   333.000000   351.000000      364.000000
#
# [8 rows x 84 columns]

# %% [markdown]
# ### First actual model using Logistic Regression. Gary: Dunk number might be able to quantify morale

# %%
df_enhanced2 = df_games.merge(
    bartovikANdf[['YEAR', 'TEAM NO', 'BADJ O', 'BADJ D', 'WIN%']],
    left_on=['YEAR', 'TEAM NO 1'],
    right_on=['YEAR', 'TEAM NO'],
    how='left'
)
df_enhanced2.rename(columns={'BADJ O': 'BADJ O 1', 'BADJ D': 'BADJ D 1', 'WIN%':'WIN% 1'}, inplace=True)
df_enhanced2.head()
# Out:
#    YEAR  ROUND  CURRENT ROUND  TEAM NO 1       TEAM 1  SEED 1  SCORE 1  \
# 0  2025      4             64       1141       Auburn       1     83.0
# 1  2025     64             64       1119   Louisville       8     75.0
# 2  2025     16             64       1114     Michigan       5     68.0
# 3  2025     32             64       1092    Texas A&M       4     80.0
# 4  2025     16             64       1112  Mississippi       6     71.0
#
#    TEAM NO 2          TEAM 2  SEED 2  SCORE 2  TEAM 1 WIN  TEAM NO  BADJ O 1  \
# 0       1145     Alabama St.      16     63.0           1     1141     133.1
# 1       1134       Creighton       9     89.0           0     1119     122.6
# 2       1089    UC San Diego      12     65.0           1     1114     115.3
# 3       1080            Yale      13     71.0           1     1092     112.5
# 4       1104  North Carolina      11     64.0           1     1112     119.4
#
#    BADJ D 1     WIN% 1
# 0      96.3  83.333333
# 1      95.3  76.470588
# 2      93.6  66.666667
# 3      92.8  56.250000
# 4      96.9  52.941176

# %%
df_enhanced2.drop('TEAM NO', axis=1, inplace=True)

df_enhanced2 = df_enhanced2.merge(
    bartovikANdf[['YEAR', 'TEAM NO', 'BADJ O', 'BADJ D', 'WIN%']],
    left_on=['YEAR', 'TEAM NO 2'],
    right_on=['YEAR', 'TEAM NO'],
    how='left'
)
df_enhanced2.rename(columns={'BADJ O': 'BADJ O 2', 'BADJ D': 'BADJ D 2', 'WIN%':'WIN% 2'}, inplace=True)
df_enhanced2.drop('TEAM NO', axis=1, inplace=True)

df_enhanced2[df_enhanced2['YEAR'] == 2024].head(10)
# Out:
#     YEAR  ROUND  CURRENT ROUND  TEAM NO 1            TEAM 1  SEED 1  SCORE 1  \
# 63  2024      1             64       1067       Connecticut       1     91.0
# 64  2024     64             64       1060  Florida Atlantic       8     65.0
# 65  2024     16             64       1029     San Diego St.       5     69.0
# 66  2024     64             64       1076            Auburn       4     76.0
# 67  2024     64             64       1073               BYU       6     67.0
# 68  2024      8             64       1054          Illinois       3     85.0
# 69  2024     32             64       1015    Washington St.       7     66.0
# 70  2024     16             64       1053          Iowa St.       2     82.0
# 71  2024     16             64       1038    North Carolina       1     90.0
# 72  2024     64             64       1044   Mississippi St.       8     51.0
#
#     TEAM NO 2            TEAM 2  SEED 2  SCORE 2  TEAM 1 WIN  BADJ O 1  \
# 63       1026           Stetson      16     52.0           1     128.5
# 64       1036      Northwestern       9     77.0           0     117.3
# 65       1020               UAB      12     65.0           1     113.0
# 66       1012              Yale      13     78.0           0     120.8
# 67       1062          Duquesne      11     71.0           0     117.3
# 68       1042      Morehead St.      14     69.0           1     129.8
# 69       1064             Drake      10     61.0           1     108.4
# 70       1027  South Dakota St.      15     65.0           1     113.6
# 71       1016            Wagner      16     62.0           1     114.9
# 72       1045      Michigan St.       9     69.0           0     112.4
#
#     BADJ D 1     WIN% 1  BADJ O 2  BADJ D 2     WIN% 2
# 63      97.3  83.333333     107.7     114.7  44.444444
# 64     103.3  63.157895     111.2      95.2  40.000000
# 65      96.5  52.631579     115.9     106.7  64.705882
# 66      94.0  66.666667     109.4      99.3  65.000000
# 67      99.9  46.666667     110.3      97.4  61.111111
# 68     103.3  68.750000     105.2     102.2  63.157895
# 69      95.2  56.250000     114.0     101.7  66.666667
# 70      90.5  56.250000     107.7     104.5  55.000000
# 71      92.7  68.421053      94.4     106.0  47.368421
# 72      93.9  52.631579     113.3      95.3  33.333333

# %%
df_enhanced2.describe()
# Out:
#               YEAR        ROUND  CURRENT ROUND    TEAM NO 1       SEED 1  \
# count  1070.000000  1070.000000    1070.000000  1070.000000  1070.000000
# mean   2016.289720    23.239252      43.314019   571.079439     4.742991
# std       5.269552    19.982938      22.371230   334.354817     3.186196
# min    2008.000000     1.000000       2.000000     1.000000     1.000000
# 25%    2012.000000     8.000000      32.000000   285.250000     2.000000
# 50%    2016.000000    16.000000      64.000000   568.000000     5.000000
# 75%    2021.000000    32.000000      64.000000   860.000000     7.000000
# max    2025.000000    64.000000      64.000000  1146.000000    16.000000
#
#            SCORE 1    TEAM NO 2       SEED 2      SCORE 2   TEAM 1 WIN  \
# count  1070.000000  1070.000000  1070.000000  1070.000000  1070.000000
# mean     72.405607   570.319626     8.813084    67.238318     0.624299
# std      12.036970   332.955556     4.819726    11.404717     0.484530
# min      39.000000     1.000000     1.000000    29.000000     0.000000
# 25%      63.250000   284.000000     4.000000    59.000000     0.000000
# 50%      72.000000   568.500000    10.000000    67.000000     1.000000
# 75%      80.750000   857.750000    13.000000    75.000000     1.000000
# max     113.000000  1147.000000    16.000000   113.000000     1.000000
#
#           BADJ O 1     BADJ D 1       WIN% 1     BADJ O 2     BADJ D 2  \
# count  1070.000000  1070.000000  1070.000000  1070.000000  1070.000000
# mean    114.752897    94.119720    65.501671   110.872430    96.918598
# std       5.915198     4.384256    15.234744     6.664236     5.094328
# min      95.900000    80.600000    16.666700    89.800000    80.600000
# 25%     110.600000    91.300000    53.333300   106.500000    93.500000
# 50%     114.600000    94.150000    64.285700   110.700000    96.500000
# 75%     118.800000    96.800000    76.470600   115.300000   100.200000
# max     133.100000   115.900000   100.000000   130.500000   115.900000
#
#             WIN% 2
# count  1070.000000
# mean     60.878379
# std      13.395840
# min      16.666700
# 25%      52.631584
# 50%      61.111100
# 75%      70.000000
# max     100.000000

# %%
df_enhanced2['BADJ O DIFF'] = df_enhanced2['BADJ O 1'] - df_enhanced2['BADJ O 2']
df_enhanced2['BADJ D DIFF'] = df_enhanced2['BADJ D 1'] - df_enhanced2['BADJ D 2']
df_enhanced2['WIN DIFF'] = df_enhanced2['WIN% 1'] - df_enhanced2['WIN% 2']

df_enhanced2.head()
# Out:
#    YEAR  ROUND  CURRENT ROUND  TEAM NO 1       TEAM 1  SEED 1  SCORE 1  \
# 0  2025      4             64       1141       Auburn       1     83.0
# 1  2025     64             64       1119   Louisville       8     75.0
# 2  2025     16             64       1114     Michigan       5     68.0
# 3  2025     32             64       1092    Texas A&M       4     80.0
# 4  2025     16             64       1112  Mississippi       6     71.0
#
#    TEAM NO 2          TEAM 2  SEED 2  ...  TEAM 1 WIN  BADJ O 1  BADJ D 1  \
# 0       1145     Alabama St.      16  ...           1     133.1      96.3
# 1       1134       Creighton       9  ...           0     122.6      95.3
# 2       1089    UC San Diego      12  ...           1     115.3      93.6
# 3       1080            Yale      13  ...           1     112.5      92.8
# 4       1104  North Carolina      11  ...           1     119.4      96.9
#
#       WIN% 1  BADJ O 2  BADJ D 2     WIN% 2  BADJ O DIFF  BADJ D DIFF  \
# 0  83.333333     100.5     107.7  47.826087         32.6        -11.4
# 1  76.470588     114.1      98.0  52.941176          8.5         -2.7
# 2  66.666667     112.6      96.5  89.473684          2.7         -2.9
# 3  56.250000     113.8     106.0  61.111111         -1.3        -13.2
# 4  52.941176     118.5     100.6  50.000000          0.9         -3.7
#
#     WIN DIFF
# 0  35.507246
# 1  23.529412
# 2 -22.807018
# 3  -4.861111
# 4   2.941176
#
# [5 rows x 21 columns]

# %%
df_enhanced2['SEED DIFF'] = df_enhanced2['SEED 1'] - df_enhanced2['SEED 2']
df_enhanced2.head()
# Out:
#    YEAR  ROUND  CURRENT ROUND  TEAM NO 1       TEAM 1  SEED 1  SCORE 1  \
# 0  2025      4             64       1141       Auburn       1     83.0
# 1  2025     64             64       1119   Louisville       8     75.0
# 2  2025     16             64       1114     Michigan       5     68.0
# 3  2025     32             64       1092    Texas A&M       4     80.0
# 4  2025     16             64       1112  Mississippi       6     71.0
#
#    TEAM NO 2          TEAM 2  SEED 2  ...  BADJ O 1  BADJ D 1     WIN% 1  \
# 0       1145     Alabama St.      16  ...     133.1      96.3  83.333333
# 1       1134       Creighton       9  ...     122.6      95.3  76.470588
# 2       1089    UC San Diego      12  ...     115.3      93.6  66.666667
# 3       1080            Yale      13  ...     112.5      92.8  56.250000
# 4       1104  North Carolina      11  ...     119.4      96.9  52.941176
#
#    BADJ O 2  BADJ D 2     WIN% 2  BADJ O DIFF  BADJ D DIFF   WIN DIFF  \
# 0     100.5     107.7  47.826087         32.6        -11.4  35.507246
# 1     114.1      98.0  52.941176          8.5         -2.7  23.529412
# 2     112.6      96.5  89.473684          2.7         -2.9 -22.807018
# 3     113.8     106.0  61.111111         -1.3        -13.2  -4.861111
# 4     118.5     100.6  50.000000          0.9         -3.7   2.941176
#
#    SEED DIFF
# 0        -15
# 1         -1
# 2         -7
# 3         -9
# 4         -5
#
# [5 rows x 22 columns]

# %%
import seaborn as sns
df_enhanced2MAP = df_enhanced2[['SEED DIFF', 'BADJ O DIFF', 'BADJ D DIFF', 'WIN DIFF', 'TEAM 1 WIN']]
correlation_matrix = df_enhanced2MAP.corr()
plt.figure(figsize=(8, 6)) # Adjust figure size for readability
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
df_enhanced2train = df_enhanced2[df_enhanced2['YEAR'] < 2023]
df_enhanced2test = df_enhanced2[df_enhanced2['YEAR'] >= 2023]
##X = df_filtered_sessions[['sim2instructor', 'sim2case','sim2book', 'ln_length','instance',
##                          'interaction', 'top_speaker']]
##y = df_filtered_sessions['ESL_val']
##X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)
X_train = df_enhanced2train[['BADJ O DIFF', 'BADJ D DIFF', 'SEED DIFF']]
X_test = df_enhanced2test[['BADJ O DIFF', 'BADJ D DIFF', 'SEED DIFF']]
y_train = df_enhanced2train['TEAM 1 WIN']
y_test = df_enhanced2test['TEAM 1 WIN']

scalar = StandardScaler()
X_train_processed = scalar.fit_transform(X_train)
X_test_processed = scalar.transform(X_test)
X_train_processed
# Out:
# array([[ 1.8032864 , -1.41395097, -1.67287779],
#        [-0.45809852, -0.29893131,  0.47731757],
#        [ 0.08775301, -0.39057676, -0.44419473],
#        ...,
#        [-0.3244206 ,  0.95355654,  0.63090295],
#        [-1.32700504, -0.405851  ,  0.63090295],
#        [ 0.93437987,  1.71726863,  0.63090295]])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
Cs= [0.1, 1, 10, 100] 
solvers= ['lbfgs', 'liblinear', 'sag', 'saga']
for solver in solvers:
    for C in Cs:
        logreg_model = LogisticRegression(random_state=1, max_iter=1000, solver=solver, C=C)
        logreg_model.fit(X_train_processed, y_train)
        y_pred = logreg_model.predict(X_test_processed)
        print(f"Solver: {solver}, C: {C}")
        print(classification_report(y_test, y_pred, digits=4))
# Out:
# Solver: lbfgs, C: 0.1
#               precision    recall  f1-score   support
#
#            0     0.7000    0.5224    0.5983        67
#            1     0.7698    0.8770    0.8199       122
#
#     accuracy                         0.7513       189
#    macro avg     0.7349    0.6997    0.7091       189
# weighted avg     0.7450    0.7513    0.7414       189
#
# Solver: lbfgs, C: 1
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: lbfgs, C: 10
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: lbfgs, C: 100
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: liblinear, C: 0.1
#               precision    recall  f1-score   support
#
#            0     0.6863    0.5224    0.5932        67
#            1     0.7681    0.8689    0.8154       122
#
#     accuracy                         0.7460       189
#    macro avg     0.7272    0.6956    0.7043       189
# weighted avg     0.7391    0.7460    0.7366       189
#
# Solver: liblinear, C: 1
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: liblinear, C: 10
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: liblinear, C: 100
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: sag, C: 0.1
#               precision    recall  f1-score   support
#
#            0     0.7000    0.5224    0.5983        67
#            1     0.7698    0.8770    0.8199       122
#
#     accuracy                         0.7513       189
#    macro avg     0.7349    0.6997    0.7091       189
# weighted avg     0.7450    0.7513    0.7414       189
#
# Solver: sag, C: 1
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: sag, C: 10
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: sag, C: 100
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: saga, C: 0.1
#               precision    recall  f1-score   support
#
#            0     0.7000    0.5224    0.5983        67
#            1     0.7698    0.8770    0.8199       122
#
#     accuracy                         0.7513       189
#    macro avg     0.7349    0.6997    0.7091       189
# weighted avg     0.7450    0.7513    0.7414       189
#
# Solver: saga, C: 1
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: saga, C: 10
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Solver: saga, C: 100
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189

# %%
###now we use the knn model

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

ks = [3, 5, 7, 9, 11, 15]
for k in ks:
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train_processed, y_train)
    y_pred = knn_model.predict(X_test_processed)
    print(f"Results for k={k}")
    print(classification_report(y_test, y_pred, digits=4))
# Out:
# Results for k=3
#               precision    recall  f1-score   support
#
#            0     0.5312    0.5075    0.5191        67
#            1     0.7360    0.7541    0.7449       122
#
#     accuracy                         0.6667       189
#    macro avg     0.6336    0.6308    0.6320       189
# weighted avg     0.6634    0.6667    0.6649       189
#
# Results for k=5
#               precision    recall  f1-score   support
#
#            0     0.5538    0.5373    0.5455        67
#            1     0.7500    0.7623    0.7561       122
#
#     accuracy                         0.6825       189
#    macro avg     0.6519    0.6498    0.6508       189
# weighted avg     0.6805    0.6825    0.6814       189
#
# Results for k=7
#               precision    recall  f1-score   support
#
#            0     0.5932    0.5224    0.5556        67
#            1     0.7538    0.8033    0.7778       122
#
#     accuracy                         0.7037       189
#    macro avg     0.6735    0.6628    0.6667       189
# weighted avg     0.6969    0.7037    0.6990       189
#
# Results for k=9
#               precision    recall  f1-score   support
#
#            0     0.6034    0.5224    0.5600        67
#            1     0.7557    0.8115    0.7826       122
#
#     accuracy                         0.7090       189
#    macro avg     0.6796    0.6669    0.6713       189
# weighted avg     0.7017    0.7090    0.7037       189
#
# Results for k=11
#               precision    recall  f1-score   support
#
#            0     0.6250    0.5224    0.5691        67
#            1     0.7594    0.8279    0.7922       122
#
#     accuracy                         0.7196       189
#    macro avg     0.6922    0.6751    0.6806       189
# weighted avg     0.7118    0.7196    0.7131       189
#
# Results for k=15
#               precision    recall  f1-score   support
#
#            0     0.5846    0.5672    0.5758        67
#            1     0.7661    0.7787    0.7724       122
#
#     accuracy                         0.7037       189
#    macro avg     0.6754    0.6729    0.6741       189
# weighted avg     0.7018    0.7037    0.7027       189

# %%
###SVC
Cs = [0.1, 0.2, 0.5, 0.8, 1, 1.2, 1.5, 2, 5, 10]
solvers = ['linear', 'rbf', 'poly', 'sigmoid']
for solver in solvers:
    for C in Cs:
        print(f"Results for solver={solver}, C={C}")
        svc_model = SVC(C=C, kernel=solver)
        svc_model.fit(X_train_processed, y_train)
        y_pred_svc = svc_model.predict(X_test_processed)
        print(classification_report(y_test, y_pred_svc, digits=4))
# Out:
# Results for solver=linear, C=0.1
#               precision    recall  f1-score   support
#
#            0     0.6667    0.5373    0.5950        67
#            1     0.7704    0.8525    0.8093       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7185    0.6949    0.7022       189
# weighted avg     0.7336    0.7407    0.7334       189
#
# Results for solver=linear, C=0.2
#               precision    recall  f1-score   support
#
#            0     0.6667    0.5373    0.5950        67
#            1     0.7704    0.8525    0.8093       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7185    0.6949    0.7022       189
# weighted avg     0.7336    0.7407    0.7334       189
#
# Results for solver=linear, C=0.5
#               precision    recall  f1-score   support
#
#            0     0.6792    0.5373    0.6000        67
#            1     0.7721    0.8607    0.8140       122
#
#     accuracy                         0.7460       189
#    macro avg     0.7257    0.6990    0.7070       189
# weighted avg     0.7392    0.7460    0.7381       189
#
# Results for solver=linear, C=0.8
#               precision    recall  f1-score   support
#
#            0     0.6792    0.5373    0.6000        67
#            1     0.7721    0.8607    0.8140       122
#
#     accuracy                         0.7460       189
#    macro avg     0.7257    0.6990    0.7070       189
# weighted avg     0.7392    0.7460    0.7381       189
#
# Results for solver=linear, C=1
#               precision    recall  f1-score   support
#
#            0     0.6792    0.5373    0.6000        67
#            1     0.7721    0.8607    0.8140       122
#
#     accuracy                         0.7460       189
#    macro avg     0.7257    0.6990    0.7070       189
# weighted avg     0.7392    0.7460    0.7381       189
#
# Results for solver=linear, C=1.2
#               precision    recall  f1-score   support
#
#            0     0.6792    0.5373    0.6000        67
#            1     0.7721    0.8607    0.8140       122
#
#     accuracy                         0.7460       189
#    macro avg     0.7257    0.6990    0.7070       189
# weighted avg     0.7392    0.7460    0.7381       189
#
# Results for solver=linear, C=1.5
#               precision    recall  f1-score   support
#
#            0     0.6792    0.5373    0.6000        67
#            1     0.7721    0.8607    0.8140       122
#
#     accuracy                         0.7460       189
#    macro avg     0.7257    0.6990    0.7070       189
# weighted avg     0.7392    0.7460    0.7381       189
#
# Results for solver=linear, C=2
#               precision    recall  f1-score   support
#
#            0     0.6792    0.5373    0.6000        67
#            1     0.7721    0.8607    0.8140       122
#
#     accuracy                         0.7460       189
#    macro avg     0.7257    0.6990    0.7070       189
# weighted avg     0.7392    0.7460    0.7381       189
#
# Results for solver=linear, C=5
#               precision    recall  f1-score   support
#
#            0     0.6923    0.5373    0.6050        67
#            1     0.7737    0.8689    0.8185       122
#
#     accuracy                         0.7513       189
#    macro avg     0.7330    0.7031    0.7118       189
# weighted avg     0.7449    0.7513    0.7429       189
#
# Results for solver=linear, C=10
#               precision    recall  f1-score   support
#
#            0     0.6923    0.5373    0.6050        67
#            1     0.7737    0.8689    0.8185       122
#
#     accuracy                         0.7513       189
#    macro avg     0.7330    0.7031    0.7118       189
# weighted avg     0.7449    0.7513    0.7429       189
#
# Results for solver=rbf, C=0.1
#               precision    recall  f1-score   support
#
#            0     0.6667    0.4478    0.5357        67
#            1     0.7431    0.8770    0.8045       122
#
#     accuracy                         0.7249       189
#    macro avg     0.7049    0.6624    0.6701       189
# weighted avg     0.7160    0.7249    0.7092       189
#
# Results for solver=rbf, C=0.2
#               precision    recall  f1-score   support
#
#            0     0.6875    0.4925    0.5739        67
#            1     0.7589    0.8770    0.8137       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7232    0.6848    0.6938       189
# weighted avg     0.7336    0.7407    0.7287       189
#
# Results for solver=rbf, C=0.5
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Results for solver=rbf, C=0.8
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Results for solver=rbf, C=1
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Results for solver=rbf, C=1.2
#               precision    recall  f1-score   support
#
#            0     0.6735    0.4925    0.5690        67
#            1     0.7571    0.8689    0.8092       122
#
#     accuracy                         0.7354       189
#    macro avg     0.7153    0.6807    0.6891       189
# weighted avg     0.7275    0.7354    0.7240       189
#
# Results for solver=rbf, C=1.5
#               precision    recall  f1-score   support
#
#            0     0.6800    0.5075    0.5812        67
#            1     0.7626    0.8689    0.8123       122
#
#     accuracy                         0.7407       189
#    macro avg     0.7213    0.6882    0.6967       189
# weighted avg     0.7333    0.7407    0.7303       189
#
# Results for solver=rbf, C=2
#               precision    recall  f1-score   support
#
#            0     0.6667    0.5075    0.5763        67
#            1     0.7609    0.8607    0.8077       122
#
#     accuracy                         0.7354       189
#    macro avg     0.7138    0.6841    0.6920       189
# weighted avg     0.7275    0.7354    0.7257       189
#
# Results for solver=rbf, C=5
#               precision    recall  f1-score   support
#
#            0     0.6600    0.4925    0.5641        67
#            1     0.7554    0.8607    0.8046       122
#
#     accuracy                         0.7302       189
#    macro avg     0.7077    0.6766    0.6844       189
# weighted avg     0.7216    0.7302    0.7193       189
#
# Results for solver=rbf, C=10
#               precision    recall  f1-score   support
#
#            0     0.6667    0.5075    0.5763        67
#            1     0.7609    0.8607    0.8077       122
#
#     accuracy                         0.7354       189
#    macro avg     0.7138    0.6841    0.6920       189
# weighted avg     0.7275    0.7354    0.7257       189
#
# Results for solver=poly, C=0.1
#               precision    recall  f1-score   support
#
#            0     0.8636    0.2836    0.4270        67
#            1     0.7126    0.9754    0.8235       122
#
#     accuracy                         0.7302       189
#    macro avg     0.7881    0.6295    0.6252       189
# weighted avg     0.7661    0.7302    0.6829       189
#
# Results for solver=poly, C=0.2
#               precision    recall  f1-score   support
#
#            0     0.8636    0.2836    0.4270        67
#            1     0.7126    0.9754    0.8235       122
#
#     accuracy                         0.7302       189
#    macro avg     0.7881    0.6295    0.6252       189
# weighted avg     0.7661    0.7302    0.6829       189
#
# Results for solver=poly, C=0.5
#               precision    recall  f1-score   support
#
#            0     0.8636    0.2836    0.4270        67
#            1     0.7126    0.9754    0.8235       122
#
#     accuracy                         0.7302       189
#    macro avg     0.7881    0.6295    0.6252       189
# weighted avg     0.7661    0.7302    0.6829       189
#
# Results for solver=poly, C=0.8
#               precision    recall  f1-score   support
#
#            0     0.8636    0.2836    0.4270        67
#            1     0.7126    0.9754    0.8235       122
#
#     accuracy                         0.7302       189
#    macro avg     0.7881    0.6295    0.6252       189
# weighted avg     0.7661    0.7302    0.6829       189
#
# Results for solver=poly, C=1
#               precision    recall  f1-score   support
#
#            0     0.8636    0.2836    0.4270        67
#            1     0.7126    0.9754    0.8235       122
#
#     accuracy                         0.7302       189
#    macro avg     0.7881    0.6295    0.6252       189
# weighted avg     0.7661    0.7302    0.6829       189
#
# Results for solver=poly, C=1.2
#               precision    recall  f1-score   support
#
#            0     0.8636    0.2836    0.4270        67
#            1     0.7126    0.9754    0.8235       122
#
#     accuracy                         0.7302       189
#    macro avg     0.7881    0.6295    0.6252       189
# weighted avg     0.7661    0.7302    0.6829       189
#
# Results for solver=poly, C=1.5
#               precision    recall  f1-score   support
#
#            0     0.8696    0.2985    0.4444        67
#            1     0.7169    0.9754    0.8264       122
#
#     accuracy                         0.7354       189
#    macro avg     0.7932    0.6370    0.6354       189
# weighted avg     0.7710    0.7354    0.6910       189
#
# Results for solver=poly, C=2
#               precision    recall  f1-score   support
#
#            0     0.8696    0.2985    0.4444        67
#            1     0.7169    0.9754    0.8264       122
#
#     accuracy                         0.7354       189
#    macro avg     0.7932    0.6370    0.6354       189
# weighted avg     0.7710    0.7354    0.6910       189
#
# Results for solver=poly, C=5
#               precision    recall  f1-score   support
#
#            0     0.8400    0.3134    0.4565        67
#            1     0.7195    0.9672    0.8252       122
#
#     accuracy                         0.7354       189
#    macro avg     0.7798    0.6403    0.6408       189
# weighted avg     0.7622    0.7354    0.6945       189
#
# Results for solver=poly, C=10
#               precision    recall  f1-score   support
#
#            0     0.8400    0.3134    0.4565        67
#            1     0.7195    0.9672    0.8252       122
#
#     accuracy                         0.7354       189
#    macro avg     0.7798    0.6403    0.6408       189
# weighted avg     0.7622    0.7354    0.6945       189
#
# Results for solver=sigmoid, C=0.1
#               precision    recall  f1-score   support
#
#            0     0.5000    0.5970    0.5442        67
#            1     0.7523    0.6721    0.7100       122
#
#     accuracy                         0.6455       189
#    macro avg     0.6261    0.6346    0.6271       189
# weighted avg     0.6629    0.6455    0.6512       189
#
# Results for solver=sigmoid, C=0.2
#               precision    recall  f1-score   support
#
#            0     0.4250    0.5075    0.4626        67
#            1     0.6972    0.6230    0.6580       122
#
#     accuracy                         0.5820       189
#    macro avg     0.5611    0.5652    0.5603       189
# weighted avg     0.6007    0.5820    0.5887       189
#
# Results for solver=sigmoid, C=0.5
#               precision    recall  f1-score   support
#
#            0     0.3919    0.4328    0.4113        67
#            1     0.6696    0.6311    0.6498       122
#
#     accuracy                         0.5608       189
#    macro avg     0.5307    0.5320    0.5306       189
# weighted avg     0.5711    0.5608    0.5653       189
#
# Results for solver=sigmoid, C=0.8
#               precision    recall  f1-score   support
#
#            0     0.4000    0.4478    0.4225        67
#            1     0.6754    0.6311    0.6525       122
#
#     accuracy                         0.5661       189
#    macro avg     0.5377    0.5395    0.5375       189
# weighted avg     0.5778    0.5661    0.5710       189
#
# Results for solver=sigmoid, C=1
#               precision    recall  f1-score   support
#
#            0     0.4000    0.4478    0.4225        67
#            1     0.6754    0.6311    0.6525       122
#
#     accuracy                         0.5661       189
#    macro avg     0.5377    0.5395    0.5375       189
# weighted avg     0.5778    0.5661    0.5710       189
#
# Results for solver=sigmoid, C=1.2
#               precision    recall  f1-score   support
#
#            0     0.4054    0.4478    0.4255        67
#            1     0.6783    0.6393    0.6582       122
#
#     accuracy                         0.5714       189
#    macro avg     0.5418    0.5436    0.5419       189
# weighted avg     0.5815    0.5714    0.5757       189
#
# Results for solver=sigmoid, C=1.5
#               precision    recall  f1-score   support
#
#            0     0.4054    0.4478    0.4255        67
#            1     0.6783    0.6393    0.6582       122
#
#     accuracy                         0.5714       189
#    macro avg     0.5418    0.5436    0.5419       189
# weighted avg     0.5815    0.5714    0.5757       189
#
# Results for solver=sigmoid, C=2
#               precision    recall  f1-score   support
#
#            0     0.4054    0.4478    0.4255        67
#            1     0.6783    0.6393    0.6582       122
#
#     accuracy                         0.5714       189
#    macro avg     0.5418    0.5436    0.5419       189
# weighted avg     0.5815    0.5714    0.5757       189
#
# Results for solver=sigmoid, C=5
#               precision    recall  f1-score   support
#
#            0     0.4110    0.4478    0.4286        67
#            1     0.6810    0.6475    0.6639       122
#
#     accuracy                         0.5767       189
#    macro avg     0.5460    0.5477    0.5462       189
# weighted avg     0.5853    0.5767    0.5805       189
#
# Results for solver=sigmoid, C=10
#               precision    recall  f1-score   support
#
#            0     0.4054    0.4478    0.4255        67
#            1     0.6783    0.6393    0.6582       122
#
#     accuracy                         0.5714       189
#    macro avg     0.5418    0.5436    0.5419       189
# weighted avg     0.5815    0.5714    0.5757       189

# %%
random_forest_model = RandomForestClassifier(random_state=8)
random_forest_model.fit(X_train_processed, y_train)
y_pred_rf = random_forest_model.predict(X_test_processed)
print(classification_report(y_test, y_pred_rf, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5625    0.5373    0.5496        67
#            1     0.7520    0.7705    0.7611       122
#
#     accuracy                         0.6878       189
#    macro avg     0.6573    0.6539    0.6554       189
# weighted avg     0.6848    0.6878    0.6862       189
